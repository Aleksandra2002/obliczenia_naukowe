# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleksandra2002/obliczenia_naukowe/blob/main/zadDomowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TYTUŁ DZIEŃ DOBRY
# ## sekcja 1

# %%
a = input("Jak masz na imię? ")
print ("witaj", a)
# Out:
# Jak masz na imię? Ola
# witaj Ola

# %% [markdown]
# #sekcja 2

# %% [markdown]
# ```python
# a = input("Jak masz na imię? ")
# print ("witaj", a)
# ````

# %% [markdown]
# #sekcja 3

# %% [markdown]
# ![pobrane.jfif](data:image/jpeg;base64,...)
